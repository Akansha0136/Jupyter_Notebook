# %%
'''
This project involves visualizing a complex employee dataset to uncover insights related to employee experience, salary, 
performance, and productivity. Using various scatter plots, we analyze the relationships between different metrics such as years
of experience, salary, performance scores, and project completion to support data-driven decisions in human resource management.
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("complex_dataset_with_random_names.csv")
df
# Out:
#        ID                 Name  Age  Gender         City  Salary Joining_Date  \
# 0       1        Arthur Bender   56    Male      Phoenix  115751   01-01-2015
# 1       2         Ryan Proctor   46  Female      Houston   55556   02-01-2015
# 2       3        Jamie Roberts   32    Male      Chicago   89042   03-01-2015
# 3       4    Taylor Washington   60   Other      Phoenix   48099   04-01-2015
# 4       5        David Maynard   25    Male  Los Angeles   75096   05-01-2015
# ..    ...                  ...  ...     ...          ...     ...          ...
# 995   996        Johnny Burton   22  Female      Chicago   45417   22-09-2017
# 996   997           Evan Kelly   40   Other      Houston   54729   23-09-2017
# 997   998  Katherine Fernandez   27   Other      Houston   60099   24-09-2017
# 998   999  Mr. Keith Moran DDS   61  Female  Los Angeles   59961   25-09-2017
# 999  1000            Amy Doyle   19  Female      Phoenix   42602   26-09-2017
#
# ...

# %%
#To determine if there's a correlation between years of experience and salary, helping evaluate fairness in compensation.
plt.scatter(df['Experience_Years'], df['Salary'], c="blue")
plt.show()

# %%
#To explore if employees who complete more projects also receive higher performance scores.
plt.scatter(df['Projects_Completed'], df['Performance_Score'], c="red")
plt.show()

# %%
#To analyze whether age influences the number of overtime hours worked, possibly indicating generational work patterns.
plt.scatter(df['Age'], df['Overtime_Hours'], c="blue")
plt.show()

# %%
#To examine how salaries have changed over employee joining dates, identifying trends in pay growth or inflation.
plt.plot(df['Joining_Date'],df['Salary'])
plt.legend(["Joining_Date", "Salary"])
plt.title("Linear graph", fontsize=25, color="green")
plt.ylabel('Salary')
plt.xlabel('Joining_Date')
plt.show()

# %%
#To track how performance scores vary with employee tenure, suggesting whether performance improves or declines over time.
plt.plot(df['Joining_Date'],df['Performance_Score'])
plt.legend(["Joining_Date", "Performance_Score"])
plt.title("Linear graph", fontsize=25, color="green")
plt.ylabel('Performance_Score')
plt.xlabel('Joining_Date')
plt.show()

# %%
#To understand how employee experience aligns with their joining date, validating tenure data accuracy.
plt.plot(df['Joining_Date'],df['Experience_Years'])
plt.legend(["Joining_Date", "Experience_Years"])
plt.title("Linear graph", fontsize=25, color="green")
plt.ylabel('Experience_Years')
plt.xlabel('Joining_Date')
plt.show()

# %%
#To check whether promotions are aligned with productivity (in terms of project completion).
plt.plot(df['Last_Promotion_Date'],df['Projects_Completed'])
plt.legend(["Last_Promotion_Date", "Projects_Completed"])
plt.title("Linear graph", fontsize=25, color="green")
plt.ylabel('Projects_Completed')
plt.xlabel('Last_Promotion_Date')
plt.show()

# %%
#To compare average or total salary distributions across departments, which can help in budget planning or fairness audits.
plt.bar(df['Department'], df['Salary'])
# Adding title to the plot
plt.title("Bar Chart")
# Adding label on the y-axis
plt.ylabel('Salary')
# Adding label on the x-axis
plt.xlabel('Department')
plt.show()

# %%
#To assess departmental productivity by evaluating total projects completed per department.
plt.bar(df['Department'], df['Projects_Completed'])
# Adding title to the plot
plt.title("Bar Chart")
# Adding label on the y-axis
plt.ylabel('Projects_Completed')
# Adding label on the x-axis
plt.xlabel('Department')
plt.show()

# %%
# Count of employees by City
city_counts = df["City"].value_counts()

# Count of employees by Department
department_counts = df["Department"].value_counts()

# Count of employees by Gender
gender_counts = df["Gender"].value_counts()

# %%
department_counts = df.groupby("Department")["ID"].count()

# %%
#To show the geographical distribution of employees and identify cities with higher or lower staff density.
city_counts.plot(kind="bar", color="skyblue", figsize=(8, 6))
plt.title("Employee Count by City")
plt.xlabel("City")
plt.ylabel("Count of Employees")
plt.xticks(rotation=45)
plt.show()

# %%
#To determine whether higher education levels correlate with greater work experience.
plt.bar(df['Education_Level'], df['Experience_Years'])
# Adding title to the plot
plt.title("Bar Chart")
# Adding label on the y-axis
plt.ylabel('Experience_Years')
# Adding label on the x-axis
plt.xlabel('Education_Level')
plt.show()

# %%
#To understand the age demographics of the workforce.
plt.hist(df["Age"])
plt.show()

# %%
#To analyze how salaries are spread among employees (e.g., skewed or normal distribution).
plt.hist(df["Salary"])
plt.title("Histogram")
plt.show()

# %%
#To examine whether performance scores are concentrated or evenly spread across employees.
plt.hist(df["Performance_Score"])
plt.title("Histogram")
plt.show()

# %%
#To visualize the proportion of employees in each department.
department_counts = df["Department"].value_counts()

# Plotting the Donut Chart
plt.figure(figsize=(7, 7))
plt.pie(
    department_counts,
    labels=department_counts.index,
    autopct='%1.1f%%',  # Show percentage
    startangle=90,  # Start from the top
    wedgeprops={'width': 0.4},  # Width of the wedges to create the donut effect
    colors=plt.cm.tab10.colors  # Set a color palette
)

# Add a central circle for the "hole"
plt.gca().add_artist(plt.Circle((0, 0), 0.7, color='white'))

# Add title
plt.title("Employee Distribution by Department")
plt.show()

# %%
#To show the distribution of marital status across the workforce for demographic insights.
marital_status_count = df["Marital_Status"].value_counts()

# Plotting the Donut Chart
plt.figure(figsize=(7, 7))
plt.pie(
    marital_status_count,
    labels=marital_status_count.index,
    autopct='%1.1f%%',  # Show percentage
    startangle=90,  # Start from the top
    wedgeprops={'width': 0.4},  # Width of the wedges to create the donut effect
    colors=plt.cm.tab10.colors  # Set a color palette
)

# Add a central circle for the "hole"
plt.gca().add_artist(plt.Circle((0, 0), 0.7, color='white'))

# Add title
plt.title("Employee Distribution by Marital_Status")
plt.show()

# %%
#To compare how many employees are remote vs non-remote.
remote_work_counts = df["Remote_Work"].value_counts()

# Plotting the Donut Chart
plt.figure(figsize=(7, 7))
plt.pie(
    remote_work_counts,
    labels=remote_work_counts.index,
    autopct='%1.1f%%',  # Show percentage
    startangle=90,  # Start from the top
    wedgeprops={'width': 0.4},  # Width of the wedges to create the donut effect
    colors=plt.cm.tab10.colors  # Set a color palette
)

# Add a central circle for the "hole"
plt.gca().add_artist(plt.Circle((0, 0), 0.7, color='white'))

# Add title
plt.title("Employee Distribution by Remote_Work")
plt.show()

# %%
#To represent the location-wise share of employees in a visually intuitive form.
city_counts = df["City"].value_counts()

# Plotting the Donut Chart
plt.figure(figsize=(7, 7))
plt.pie(
    city_counts,
    labels=city_counts.index,
    autopct='%1.1f%%',  # Show percentage
    startangle=90,  # Start from the top
    wedgeprops={'width': 0.4},  # Width of the wedges to create the donut effect
    colors=plt.cm.tab10.colors  # Set a color palette
)

# Add a central circle for the "hole"
plt.gca().add_artist(plt.Circle((0, 0), 0.7, color='white'))

# Add title
plt.title("City")
plt.show()

# %%
#To provide a gender diversity snapshot within the organization.
gender_counts = df["Gender"].value_counts()

# Plotting the Pie Chart
plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct='%1.1f%%',  # Show percentages
    startangle=90  # Start from the top
)

# Add a title
plt.title("Employee Distribution by Gender")
plt.show()

# %%
#To visualize the educational qualification levels of employees.
education_level = df["Education_Level"].value_counts()

# Plotting the Pie Chart
plt.pie(
    education_level,
    labels=education_level.index,
    autopct='%1.1f%%',  # Show percentages
    startangle=90  # Start from the top
)

# Add a title
plt.title("Employee Distribution by Education_Level")
plt.show()

# %%
#To offer another visual perspective on geographical distribution of employees.
city_counts = df["City"].value_counts()

# Plotting the Pie Chart
plt.pie(
    city_counts,
    labels=city_counts.index,
    autopct='%1.1f%%',  # Show percentages
    startangle=90  # Start from the top
)

# Add a title
plt.title("Employee Distribution by City")
plt.show()

# %%
'''
This employee data visualization project provides key insights into workforce demographics, compensation, performance, and 
productivity. The visual analysis reveals patterns such as the positive correlation between experience and salary, the impact of
project completion on performance scores, and department-wise variations in compensation and output. It also highlights 
organizational diversity in terms of gender, education, and geographic distribution. These insights can guide strategic HR 
decisions, such as equitable salary structuring, targeted performance improvement, and resource planning.
'''
